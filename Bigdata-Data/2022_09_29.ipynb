# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random as rd

plt.hist([1, 1, 2, 3, 4, 5, 6, 6, 7, 8, 10])
plt.show()

# %%
dice = rd.randint(1, 6)
print(dice)
# Out:
# 5

# %%
dice = []
for i in range(1000):
    dice.append(rd.randint(1, 6))
plt.hist(dice, bins=20)
plt.show()

# %%
import csv
df = pd.read_csv("./Seoul_Temp_Test.csv", encoding="cp949")
df = csv.reader(df)


result = []

for row in df:
    if row[-1] != ' ':
        result.append(row[-1])

plt.hist(result, bins = 100, color='purple')
plt.show()

# %%
print(result)
# Out:
# ['1907.10.1', '108', '13.5', '7.9', '20.7']
